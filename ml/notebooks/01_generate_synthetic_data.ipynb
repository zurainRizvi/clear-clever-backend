# %% [markdown]
# # 01 — Generate synthetic ClearClever training data

# %%
# !pip install -q -r ../requirements.txt
# %cd ..

# %%
# !python scripts/generate_synthetic_claims.py --rows 10000
# !python scripts/generate_synthetic_fraud.py --rows 10000
# !python scripts/generate_synthetic_recommendations.py --journeys 10000
# !python scripts/analyze_datasets.py
