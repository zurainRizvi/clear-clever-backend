# %% [markdown]
# # 03 — Train fraud ML model and export fraud_v1.json

# %%
# !pip install -q -r ../requirements.txt
# %cd ..
# !python scripts/generate_synthetic_fraud.py
# !python scripts/export_for_node.py --model fraud

import json
from pathlib import Path
print(json.loads(Path('reports/fraud_metrics.json').read_text()))
